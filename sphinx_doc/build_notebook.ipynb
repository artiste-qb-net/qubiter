# %% [markdown]
# <a href="./build/html/index.html">open home directory</a>

# %%
refresh_static_folder = False

from shutil import copyfile
if refresh_static_folder:
    sphinx_prefix = 'source/_static/'
    home_prefix = '../qubiter/'
    cg_name = 'classgraph.pdf'
    cgo_name = 'classgraph_orphans.html'
    ros_name = 'qubiter_rosetta_stone.pdf'
    copyfile(home_prefix + cg_name, sphinx_prefix + cg_name)
    copyfile(home_prefix + cgo_name, sphinx_prefix + cgo_name)
    copyfile(home_prefix + ros_name, sphinx_prefix + ros_name)

# %%
# !sphinx-apidoc --separate -f -o source/ ../qubiter
# Out:
# Creating file source/qubiter.rst.
# Creating file source/qubiter.BitVector.rst.
# Creating file source/qubiter.CGateExpander.rst.
# Creating file source/qubiter.CGateSEO_writer.rst.
# Creating file source/qubiter.CktEmbedder.rst.
# Creating file source/qubiter.CodaSEO_writer.rst.
# Creating file source/qubiter.Controls.rst.
# Creating file source/qubiter.EchoingSEO_reader.rst.
# Creating file source/qubiter.FouSEO_writer.rst.
# Creating file source/qubiter.HadamardTransform.rst.
# Creating file source/qubiter.LoopFileGenerator.rst.
# Creating file source/qubiter.LoopyPlaceholderManager.rst.
# Creating file source/qubiter.OneBitGates.rst.
# Creating file source/qubiter.PlaceholderManager.rst.
# Creating file source/qubiter.Plotter.rst.
# Creating file source/qubiter.SEO_Lista.rst.
# Creating file source/qubiter.SEO_MatrixProduct.rst.
# Creating file source/qubiter.SEO_pre_reader.rst.
# Creating file source/qubiter.SEO_reader.rst.
# Creating file source/qubiter.SEO_simulator.rst.
# Creating file source/qubiter.SEO_simulator_tf.rst.
# Creating file source/qubiter.SEO_writer.rst.
# Creating file source/qubiter.StateVec.rst.
# Creating file source/qubiter.UnitaryMat.rst.
# Creating file source/qubiter.classgraph.rst.
# Creating file source/qubiter.run_all_nb.rst.
# Creating file source/qubiter.run_all_py.rst.
# Creating file source/qubiter.utilities_gen.rst.
# Creating file source/qubiter.adv_applications.rst.
# Creating file source/qubiter.adv_applications.CostMinimizer.rst.
# Creating file source/qubiter.adv_applications.MeanHamil.rst.
# Creating file source/qubiter.adv_applications.MeanHamilMinimizer.rst.
# Creating file source/qubiter.adv_applications.MeanHamil_native.rst.
# Creating file source/qubiter.adv_applications.MeanHamil_rigetti.rst.
# Creating file source/qubiter.adv_applications.PhaseEstSEO_writer.rst.
# Creating file source/qubiter.adv_applications.StairsAllDeriv_native.rst.
# Creating file source/qubiter.adv_applications.StairsAllDeriv_rigetti.rst.
# Creating file source/qubiter.adv_applications.StairsCkt_writer.rst.
# Creating file source/qubiter.adv_applications.StairsDeriv.rst.
# Creating file source/qubiter.adv_applications.StairsDerivCkt_writer.rst.
# Creating file source/qubiter.adv_applications.StairsDerivThrCkt_writer.rst.
# Creating file source/qubiter.adv_applications.StairsDeriv_native.rst.
# Creating file source/qubiter.adv_applications.StairsDeriv_rigetti.rst.
# Creating file source/qubiter.adv_applications.setup_autograd.rst.
# Creating file source/qubiter.device_specific.rst.
# Creating file source/qubiter.device_specific.ChipCouplingsFitter.rst.
# Creating file source/qubiter.device_specific.ForbiddenCNotExpander.rst.
# Creating file source/qubiter.device_specific.QbitPlanarLattice.rst.
# Creating file source/qubiter.device_specific.Qubiter_to_AnyQasm.rst.
# Creating file source/qubiter.device_specific.Qubiter_to_GoogleCirq.rst.
# Creating file source/qubiter.device_specific.Qubiter_to_IBMqasm.rst.
# Creating file source/qubiter.device_specific.Qubiter_to_PennyLane.rst.
# Creating file source/qubiter.device_specific.Qubiter_to_RigettiPyQuil.rst.
# Creating file source/qubiter.device_specific.RigettiTools.rst.
# Creating file source/qubiter.device_specific.chip_couplings_google.rst.
# Creating file source/qubiter.device_specific.chip_couplings_ibm.rst.
# Creating file source/qubiter.device_specific.chip_couplings_rigetti.rst.
# Creating file source/qubiter.device_specific.utilities_ds.rst.
# Creating file source/qubiter.io_folder.rst.
# Creating file source/qubiter.io_folder.loop_gen_test_4_loop.rst.
# Creating file source/qubiter.io_folder.loop_gen_test_4_loop1.rst.
# Creating file source/qubiter.io_folder.qbtr2penny_test1_PennyL.rst.
# Creating file source/qubiter.io_folder.qbtr2penny_test2_PennyL.rst.
# Creating file source/qubiter.io_folder.qbtr2penny_test2_fun_defs.rst.
# Creating file source/qubiter.jupyter_notebooks.rst.
# Creating file source/qubiter.jupyter_notebooks.utilities_nb.rst.
# Creating file source/qubiter.latex_tools.rst.
# Creating file source/qubiter.latex_tools.AsciiPic_to_Latex.rst.
# Creating file source/qubiter.quantum_CSD_compiler.rst.
# Creating file source/qubiter.quantum_CSD_compiler.CS_Decomp.rst.
# Creating file source/qubiter.quantum_CSD_compiler.DiagUnitaryExpander.rst.
# Creating file source/qubiter.quantum_CSD_compiler.DiagUnitarySEO_writer.rst.
# Creating file source/qubiter.quantum_CSD_compiler.MultiplexorExpander.rst.
# Creating file source/qubiter.quantum_CSD_compiler.MultiplexorSEO_writer.rst.
# Creating file source/qubiter.quantum_CSD_compiler.Node.rst.
# Creating file source/qubiter.quantum_CSD_compiler.Tree.rst.
# Creating file source/modules.rst.

# %%
# %system make html O=-a
# Out:
# ['Running Sphinx v2.1.0',
#  'loading pickled environment... done',
#  'building [mo]: targets for 0 po files that are out of date',
#  'building [html]: targets for 0 source files that are out of date',
#  'updating environment: [] 0 added, 4 changed, 0 removed',
#  'reading sources... [ 25%] qubiter                                              ',
#  'reading sources... [ 50%] qubiter.classgraph                                   ',
#  'reading sources... [ 75%] qubiter.run_all_nb                                   ',
#  'reading sources... [100%] qubiter.run_all_py                                   ',
#  '',
#  "C:\\Users\\rrtuc\\Desktop\\backed-up\\python-projects\\qubiter\\sphinx_doc\\source\\qubiter.rst:7: WARNING: toctree contains reference to excluded document 'qubiter.io_folder'",
#  "WARNING: autodoc: failed to import module 'classgraph' from module 'qubiter'; the following exception was raised:",
#  'Traceback (most recent call last):',
#  '  File "C:\\Users\\rrtuc\\Anaconda3\\lib\\site-packages\\sphinx\\ext\\autodoc\\importer.py", line 36, in import_module',
#  '    __import__(modname)',
#  '  File "C:\\Users\\rrtuc\\Desktop\\backed-up\\python-projects\\qubiter\\qubiter\\classgraph.py", line 35, in <module>',
#  '    for fname in os.listdir(dir_name):',
#  "FileNotFoundError: [WinError 3] The system cannot find the path specified: 'adv_applications'",
#  '',
#  "WARNING: autodoc: failed to import module 'run_all_nb' from module 'qubiter'; the following exception was raised:",
#  'Traceback (most recent call last):',
#  '  File "C:\\Users\\rrtuc\\Anaconda3\\lib\\site-packages\\sphinx\\ext\\autodoc\\importer.py", line 36, in import_module',
#  '    __import__(modname)',
#  '  File "C:\\Users\\rrtuc\\Desktop\\backed-up\\python-projects\\qubiter\\qubiter\\run_all_nb.py", line 9, in <module>',
#  '    for fname in os.listdir(dir_name):',
#  "FileNotFoundError: [WinError 3] The system cannot find the path specified: 'jupyter_notebooks'",
#  '',
#  "WARNING: autodoc: failed to import module 'run_all_py' from module 'qubiter'; the following exception was raised:",
#  'Traceback (most recent call last):',
#  '  File "C:\\Users\\rrtuc\\Anaconda3\\lib\\site-packages\\sphinx\\ext\\autodoc\\importer.py", line 36, in import_module',
#  '    __import__(modname)',
#  '  File "C:\\Users\\rrtuc\\Desktop\\backed-up\\python-projects\\qubiter\\qubiter\\run_all_py.py", line 22, in <module>',
#  '    for fname in os.listdir(dir_name):',
#  "FileNotFoundError: [WinError 3] The system cannot find the path specified: 'adv_applications'",
#  '',
#  'looking for now-outdated files... none found',
#  'pickling environment... done',
#  "checking consistency... C:\\Users\\rrtuc\\Desktop\\backed-up\\python-projects\\qubiter\\sphinx_doc\\source\\modules.rst: WARNING: document isn't included in any toctree",
#  'done',
#  'preparing documents... done',
#  'writing output... [ 16%] index                                                 ',
#  'writing output... [ 33%] modules                                               ',
#  'writing output... [ 50%] qubiter                                               ',
#  'writing output... [ 66%] qubiter.classgraph                                    ',
#  'writing output... [ 83%] qubiter.run_all_nb                                    ',
#  'writing output... [100%] qubiter.run_all_py                                    ',
#  '',
#  'generating indices... genindex py-modindex',
#  'highlighting module code... [  1%] numpy                                       ',
#  'highlighting module code... [  3%] qubiter.BitVector                           ',
#  'highlighting module code... [  4%] qubiter.CGateExpander                       ',
#  'highlighting module code... [  6%] qubiter.CGateSEO_writer                     ',
#  'highlighting module code... [  7%] qubiter.CktEmbedder                         ',
#  'highlighting module code... [  9%] qubiter.CodaSEO_writer                      ',
#  'highlighting module code... [ 11%] qubiter.Controls                            ',
#  'highlighting module code... [ 12%] qubiter.EchoingSEO_reader                   ',
#  'highlighting module code... [ 14%] qubiter.FouSEO_writer                       ',
#  'highlighting module code... [ 15%] qubiter.HadamardTransform                   ',
#  'highlighting module code... [ 17%] qubiter.LoopFileGenerator                   ',
#  'highlighting module code... [ 19%] qubiter.LoopyPlaceholderManager             ',
#  'highlighting module code... [ 20%] qubiter.OneBitGates                         ',
#  'highlighting module code... [ 22%] qubiter.PlaceholderManager                  ',
#  'highlighting module code... [ 23%] qubiter.Plotter                             ',
#  'highlighting module code... [ 25%] qubiter.SEO_Lista                           ',
#  'highlighting module code... [ 26%] qubiter.SEO_MatrixProduct                   ',
#  'highlighting module code... [ 28%] qubiter.SEO_pre_reader                      ',
#  'highlighting module code... [ 30%] qubiter.SEO_reader                          ',
#  'highlighting module code... [ 31%] qubiter.SEO_simulator                       ',
#  'highlighting module code... [ 33%] qubiter.SEO_simulator_tf                    ',
#  'highlighting module code... [ 34%] qubiter.SEO_writer                          ',
#  'highlighting module code... [ 36%] qubiter.StateVec                            ',
#  'highlighting module code... [ 38%] qubiter.UnitaryMat                          ',
#  'highlighting module code... [ 39%] qubiter.adv_applications.CostMinimizer      ',
#  'highlighting module code... [ 41%] qubiter.adv_applications.MeanHamil          ',
#  'highlighting module code... [ 42%] qubiter.adv_applications.MeanHamilMinimizer ',
#  'highlighting module code... [ 44%] qubiter.adv_applications.MeanHamil_native   ',
#  'highlighting module code... [ 46%] qubiter.adv_applications.MeanHamil_rigetti  ',
#  'highlighting module code... [ 47%] qubiter.adv_applications.PhaseEstSEO_writer ',
#  'highlighting module code... [ 49%] qubiter.adv_applications.StairsAllDeriv_native',
#  'highlighting module code... [ 50%] qubiter.adv_applications.StairsAllDeriv_rigetti',
#  'highlighting module code... [ 52%] qubiter.adv_applications.StairsCkt_writer   ',
#  'highlighting module code... [ 53%] qubiter.adv_applications.StairsDeriv        ',
#  'highlighting module code... [ 55%] qubiter.adv_applications.StairsDerivCkt_writer',
#  'highlighting module code... [ 57%] qubiter.adv_applications.StairsDerivThrCkt_writer',
#  'highlighting module code... [ 58%] qubiter.adv_applications.StairsDeriv_native ',
#  'highlighting module code... [ 60%] qubiter.adv_applications.StairsDeriv_rigetti',
#  'highlighting module code... [ 61%] qubiter.adv_applications.setup_autograd     ',
#  'highlighting module code... [ 63%] qubiter.device_specific.ChipCouplingsFitter ',
#  'highlighting module code... [ 65%] qubiter.device_specific.ForbiddenCNotExpander',
#  'highlighting module code... [ 66%] qubiter.device_specific.QbitPlanarLattice   ',
#  'highlighting module code... [ 68%] qubiter.device_specific.Qubiter_to_AnyQasm  ',
#  'highlighting module code... [ 69%] qubiter.device_specific.Qubiter_to_GoogleCirq',
#  'highlighting module code... [ 71%] qubiter.device_specific.Qubiter_to_IBMqasm  ',
#  'highlighting module code... [ 73%] qubiter.device_specific.Qubiter_to_PennyLane',
#  'highlighting module code... [ 74%] qubiter.device_specific.Qubiter_to_RigettiPyQuil',
#  'highlighting module code... [ 76%] qubiter.device_specific.RigettiTools        ',
#  'highlighting module code... [ 77%] qubiter.device_specific.chip_couplings_google',
#  'highlighting module code... [ 79%] qubiter.device_specific.chip_couplings_ibm  ',
#  'highlighting module code... [ 80%] qubiter.device_specific.chip_couplings_rigetti',
#  'highlighting module code... [ 82%] qubiter.device_specific.utilities_ds        ',
#  'highlighting module code... [ 84%] qubiter.jupyter_notebooks.utilities_nb      ',
#  'highlighting module code... [ 85%] qubiter.jupyter_notebooks.utilities_widgets ',
#  'highlighting module code... [ 87%] qubiter.latex_tools.AsciiPic_to_Latex       ',
#  'highlighting module code... [ 88%] qubiter.quantum_CSD_compiler.CS_Decomp      ',
#  'highlighting module code... [ 90%] qubiter.quantum_CSD_compiler.DiagUnitaryExpander',
#  'highlighting module code... [ 92%] qubiter.quantum_CSD_compiler.DiagUnitarySEO_writer',
#  'highlighting module code... [ 93%] qubiter.quantum_CSD_compiler.MultiplexorExpander',
#  'highlighting module code... [ 95%] qubiter.quantum_CSD_compiler.MultiplexorSEO_writer',
#  'highlighting module code... [ 96%] qubiter.quantum_CSD_compiler.Node           ',
#  'highlighting module code... [ 98%] qubiter.quantum_CSD_compiler.Tree           ',
#  'highlighting module code... [100%] qubiter.utilities_gen                       ',
#  '',
#  'writing additional pages... searchC:\\Users\\rrtuc\\Anaconda3\\lib\\site-packages\\sphinx_rtd_theme\\search.html:20: RemovedInSphinx30Warning: To modify script_files in the theme is deprecated. Please insert a <script> tag directly in your theme instead.',
#  '  {{ super() }}',
#  '',
#  'copying static files... done',
#  'copying extra files... done',
#  'dumping search index in English (code: en) ... done',
#  'dumping object inventory... done',
#  'build succeeded, 5 warnings.',
#  '',
#  'The HTML pages are in build\\html.']
